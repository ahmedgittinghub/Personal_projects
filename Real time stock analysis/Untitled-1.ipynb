# %%
print("hello world")
# Out:
# hello world

# %%
import pandas_datareader

# %%
from pandas_datareader import data

# %%
from pandas_datareader._utils import RemoteDataError

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import numpy as np

# %%
from datetime import datetime

# %%
from datetime import datetime, timedelta

# setting start date and the end date 
current_date = datetime.now()

start_date = current_date - timedelta(days=7)

# Format the start date as a string
start_date_str = start_date.strftime("%Y-%m-%d")
current_date_str = current_date.strftime("%Y-%m-%d")

# %%
current_date_str
# Out:
# '2024-03-10'

# %%
start_date_str
# Out:
# '2024-03-03'

# %%
import numpy as np
import pandas as pd
import yfinance as yf
yf.pdr_override()
from pandas_datareader import data as wb

# %%
aapl = yf.download('AAPL', start=start_date_str)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
aapl
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2024-03-04  176.149994  176.899994  173.789993  175.100006  175.100006
# 2024-03-05  170.759995  172.039993  169.619995  170.119995  170.119995
# 2024-03-06  171.059998  171.240005  168.679993  169.119995  169.119995
# 2024-03-07  169.149994  170.729996  168.490005  169.000000  169.000000
# 2024-03-08  169.000000  173.699997  168.940002  170.729996  170.729996
#
#               Volume
# Date
# 2024-03-04  81510100
# 2024-03-05  95132400
# 2024-03-06  68587700
# 2024-03-07  71765100
# 2024-03-08  76114600

# %%
import bs4 as bs
import requests

# %%
resp = requests.get('http://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
soup = bs.BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'class': 'wikitable sortable'})

# %%
tickers = []

for row in table.findAll('tr')[1:]:
    ticker = row.findAll('td')[0].text
    tickers.append(ticker)

# %%
print(tickers)
# Out:
# ['MMM\n', 'AOS\n', 'ABT\n', 'ABBV\n', 'ACN\n', 'ADBE\n', 'AMD\n', 'AES\n', 'AFL\n', 'A\n', 'APD\n', 'ABNB\n', 'AKAM\n', 'ALB\n', 'ARE\n', 'ALGN\n', 'ALLE\n', 'LNT\n', 'ALL\n', 'GOOGL\n', 'GOOG\n', 'MO\n', 'AMZN\n', 'AMCR\n', 'AEE\n', 'AAL\n', 'AEP\n', 'AXP\n', 'AIG\n', 'AMT\n', 'AWK\n', 'AMP\n', 'AME\n', 'AMGN\n', 'APH\n', 'ADI\n', 'ANSS\n', 'AON\n', 'APA\n', 'AAPL\n', 'AMAT\n', 'APTV\n', 'ACGL\n', 'ADM\n', 'ANET\n', 'AJG\n', 'AIZ\n', 'T\n', 'ATO\n', 'ADSK\n', 'ADP\n', 'AZO\n', 'AVB\n', 'AVY\n', 'AXON\n', 'BKR\n', 'BALL\n', 'BAC\n', 'BK\n', 'BBWI\n', 'BAX\n', 'BDX\n', 'BRK.B\n', 'BBY\n', 'BIO\n', 'TECH\n', 'BIIB\n', 'BLK\n', 'BX\n', 'BA\n', 'BKNG\n', 'BWA\n', 'BXP\n', 'BSX\n', 'BMY\n', 'AVGO\n', 'BR\n', 'BRO\n', 'BF.B\n', 'BLDR\n', 'BG\n', 'CDNS\n', 'CZR\n', 'CPT\n', 'CPB\n', 'COF\n', 'CAH\n', 'KMX\n', 'CCL\n', 'CARR\n', 'CTLT\n', 'CAT\n', 'CBOE\n', 'CBRE\n', 'CDW\n', 'CE\n', 'COR\n', 'CNC\n', 'CNP\n', 'CF\n', 'CHRW\n', 'CRL\n', 'SCHW\n', 'CHTR\n', 'CVX\n', 'CMG\n', 'CB\n', 'CHD\n', 
# ...

# %%
tickers = [s.replace('\n', '') for s in tickers]
tickers = sorted(tickers)

# %%
data = yf.download(tickers, start=start_date, end="2024-03-08")
# Out:
# [*********************100%%**********************]  503 of 503 completed
#
# 2 Failed downloads:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2024-03-03 18:22:14.047282 -> 2024-03-08)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')

# %%
# apple_data = data.loc[:, 'AAPL']
# print(apple_data)
data
# Out:
# Price        Adj Close                                                         \
# Ticker               A    AAL        AAPL        ABBV        ABNB         ABT
# Date
# 2024-03-04  142.860001  14.81  175.100006  177.050003  158.089996  120.040001
# 2024-03-05  144.350006  14.67  170.119995  179.160004  159.330002  118.480003
# 2024-03-06  146.220001  14.88  169.119995  181.059998  163.869995  119.339996
# 2024-03-07  149.309998  14.90  169.000000  180.570007  163.539993  120.919998
#
# Price                                                      ...   Volume  \
# Ticker           ACGL         ACN        ADBE         ADI  ...     WYNN
# Date                                                       ...
# 2024-03-04  87.139999  383.709991  567.940002  194.660004  ...  1875100
# 2024-03-05  87.389999  376.880005  544.840027  189.800003  ...  1380000
# 2024-03-06  88.820000  380.829987  543.090027  191.699997  ...  1125800
# ...

# %%
data['Adj Close']['BF.B']
# Out:
# Date
# 2024-03-04   NaN
# 2024-03-05   NaN
# 2024-03-06   NaN
# 2024-03-07   NaN
# Name: BF.B, dtype: float64

# %%
data['Adj Close']['BRK.B']
# Out:
# Date
# 2024-03-04   NaN
# 2024-03-05   NaN
# 2024-03-06   NaN
# 2024-03-07   NaN
# Name: BRK.B, dtype: float64

# %%
# Must remove data with nan values
data.dropna(axis=1)
# Out:
# Price        Adj Close                                                         \
# Ticker               A    AAL        AAPL        ABBV        ABNB         ABT
# Date
# 2024-03-04  142.860001  14.81  175.100006  177.050003  158.089996  120.040001
# 2024-03-05  144.350006  14.67  170.119995  179.160004  159.330002  118.480003
# 2024-03-06  146.220001  14.88  169.119995  181.059998  163.869995  119.339996
# 2024-03-07  149.309998  14.90  169.000000  180.570007  163.539993  120.919998
#
# Price                                                      ...   Volume  \
# Ticker           ACGL         ACN        ADBE         ADI  ...     WYNN
# Date                                                       ...
# 2024-03-04  87.139999  383.709991  567.940002  194.660004  ...  1875100
# 2024-03-05  87.389999  376.880005  544.840027  189.800003  ...  1380000
# 2024-03-06  88.820000  380.829987  543.090027  191.699997  ...  1125800
# ...

# %%
data
# Out:
# Price        Adj Close                                                         \
# Ticker               A    AAL        AAPL        ABBV        ABNB         ABT
# Date
# 2024-03-04  142.860001  14.81  175.100006  177.050003  158.089996  120.040001
# 2024-03-05  144.350006  14.67  170.119995  179.160004  159.330002  118.480003
# 2024-03-06  146.220001  14.88  169.119995  181.059998  163.869995  119.339996
# 2024-03-07  149.309998  14.90  169.000000  180.570007  163.539993  120.919998
#
# Price                                                      ...   Volume  \
# Ticker           ACGL         ACN        ADBE         ADI  ...     WYNN
# Date                                                       ...
# 2024-03-04  87.139999  383.709991  567.940002  194.660004  ...  1875100
# 2024-03-05  87.389999  376.880005  544.840027  189.800003  ...  1380000
# 2024-03-06  88.820000  380.829987  543.090027  191.699997  ...  1125800
# ...

# %%
# check for nan values
data.isnull().values.any()
# Out:
# True

# %%
# Must come up with a code or function that would delete all NAN values.
data1 = data.dropna(axis=1)

# %%
# now to make meanful date we have to find the top prefomring stock in terms of earnings 
# the stocks with the highest closing price
# dict1 = {'Stock_ticker':'', 'Stock_Returns':''}
# for ticker[0] in data1.columns.levels[0][1:]:
#         close_prices = data1[stock_ticker]['Close']
#         # calculating raturns
#         returns_calculation = close_prices.pct_change()
#          # workout the percentage change for the date period inserted
#         returns = returns_calculation.loc[date1:date2]
#         returns_df[stock_ticker] = returns

# %%
# this here is me trying to develop a way
data_p = {'Name': ['Ankit', 'Amit',
                 'Aishwarya', 'Priyanka'],
        'Age': [21, 19, 20, 18]}
 
# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data, columns=['Name', 'Age'])

df1['Name']

data_p2 = ['Ankit', 'Amit','Aishwarya', 'Priyanka','Abdi']
data_p3 = []
for name in data_p2:
    if name  in df1['Name'].values:
        print(name)
        data_p3.append(name)
# Out:
# Ankit
# Amit
# Aishwarya
# Priyanka

# %%
tickers1 = []

# Assuming data is your DataFrame
for ticker in tickers:
    # Check if the ticker is in any level of the columns MultiIndex
    
    if any(ticker in level for level in data.columns.levels):
        print(f"{ticker} found in the DataFrame")
        tickers1.append(ticker)
    
    elif any(ticker not in level for level  in data.columns.levels):
        print(f"{ticker} not found in the DataFrame")


# The tickers1 list now contains the tickers present in the DataFrame
print(tickers1)
# Out:
# A found in the DataFrame
# AAL found in the DataFrame
# AAPL found in the DataFrame
# ABBV found in the DataFrame
# ABNB found in the DataFrame
# ABT found in the DataFrame
# ACGL found in the DataFrame
# ACN found in the DataFrame
# ADBE found in the DataFrame
# ADI found in the DataFrame
# ADM found in the DataFrame
# ADP found in the DataFrame
# ADSK found in the DataFrame
# AEE found in the DataFrame
# AEP found in the DataFrame
# AES found in the DataFrame
# AFL found in the DataFrame
# AIG found in the DataFrame
# AIZ found in the DataFrame
# AJG found in the DataFrame
# AKAM found in the DataFrame
# ALB found in the DataFrame
# ALGN found in the DataFrame
# ALL found in the DataFrame
# ALLE found in the DataFrame
# AMAT found in the DataFrame
# AMCR found in the DataFrame
# AMD found in the DataFrame
# AME found in the DataFrame
# AMGN found in the DataFrame
# AMP found in the DataFrame
# AMT found in the DataFrame
# AMZN found in the DataFrame
# ANET found in the DataFrame
# ...

# %%
'BRK.B' in tickers1
# Out:
# False

# %%
data1['Adj Close'][tickers1]
# Out:
# Empty DataFrame
# Columns: []
# Index: [2024-03-04 00:00:00, 2024-03-05 00:00:00, 2024-03-06 00:00:00, 2024-03-07 00:00:00]

# %%
# Out:
# []
