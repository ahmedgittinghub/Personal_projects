# %%
#importing the the important packages


import pandas as pd
import numpy as np
import datetime


from pandas_datareader import data
import seaborn as sns

# %%
df = pd.read_pickle('all_banks')

# %%
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# Bank Ticker                    ...     MS                                \
# Stock Info    Close    Volume  ...   Open   High    Low  Close   Volume
# Date                           ...
# 2006-01-03   492.90   1537660  ...  57.17  58.49  56.74  58.31  5377000
# 2006-01-04   483.80   1871020  ...  58.70  59.28  58.35  58.35  7977800
# 2006-01-05   486.20   1143160  ...  58.55  58.59  58.02  58.51  5778000
# 2006-01-06   486.20   1370250  ...  58.77  58.85  58.05  58.57  6889800
# 2006-01-09   483.90   1680740  ...  58.63  59.29  58.62  59.19  4144500
# ...             ...       ...  ...    ...    ...    ...    ...      ...
# 2015-12-24    52.71   4671254  ...  32.57  32.71  32.44  32.48  2798163
# 2015-12-28    52.38   8761743  ...  32.36  32.36  31.95  32.17  5420280
# 2015-12-29    52.98  10155134  ...  32.44  32.70  32.32  32.55  6388244
# 2015-12-30    52.30   8763337  ...  32.50  32.64  32.20  32.23  5057162
# 2015-12-31    51.75  11281771  ...  31.91  32.30  31.77  31.81  8154307
#
# Bank Ticker    WFC
# Stock Info    Open   High    Low  Close    Volume
# Date
# 2006-01-03   31.60  31.98  31.20  31.90  11016400
# 2006-01-04   31.80  31.82  31.36  31.53  10871000
# 2006-01-05   31.50  31.56  31.31  31.50  10158000
# 2006-01-06   31.58  31.78  31.38  31.68   8403800
# 2006-01-09   31.68  31.82  31.56  31.68   5619600
# ...            ...    ...    ...    ...       ...
# 2015-12-24   54.97  55.09  54.71  54.82   4999417
# 2015-12-28   54.55  54.78  54.17  54.68   8288841
# 2015-12-29   55.11  55.35  54.99  55.29   7894876
# 2015-12-30   55.27  55.31  54.79  54.89   8016893
# 2015-12-31   54.51  54.95  54.22  54.36  10929767
#
# [2517 rows x 30 columns]

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# 2006-01-06   1370250  ...  58.77  58.85  58.05  58.57  6889800  31.58  31.78
# 2006-01-09   1680740  ...  58.63  59.29  58.62  59.19  4144500  31.68  31.82
#
# Bank Ticker
# Stock Info     Low  Close    Volume
# Date
# 2006-01-03   31.20  31.90  11016400
# 2006-01-04   31.36  31.53  10871000
# 2006-01-05   31.31  31.50  10158000
# 2006-01-06   31.38  31.68   8403800
# 2006-01-09   31.56  31.68   5619600
#
# [5 rows x 30 columns]

# %%
# viewing the highest close price for each stock 
df.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %%
df['BAC']['Close'].pct_change()
# Out:
# Date
# 2006-01-03         NaN
# 2006-01-04   -0.010620
# 2006-01-05    0.001288
# 2006-01-06   -0.001501
# 2006-01-09    0.000644
#                 ...
# 2015-12-24   -0.004037
# 2015-12-28   -0.008107
# 2015-12-29    0.008757
# 2015-12-30   -0.013310
# 2015-12-31   -0.012903
# Name: Close, Length: 2517, dtype: float64

# %%
    
   
start_date = '2006-01-01'
end_date = '2016-01-01'

# Create an empty DataFrame to store the percentage changes
returns_df = pd.DataFrame()

# Iterate over the unique stock tickers (excluding the 'Stock Info' level)
for stock_ticker in df.columns.levels[0][1:]:
    # Extract the 'Close' column for the current stock ticker
    close_prices = df[stock_ticker]['Close']

    # Calculate the percentage change over the entire period
    returns_calculation = close_prices.pct_change()

    # Get the percentage change for the specified date range
    returns = returns_calculation.loc[start_date:end_date]

    # Append the percentage changes to the returns_df DataFrame
    returns_df[stock_ticker] = returns

    # Print the final percentage change for the current stock ticker
    print(f"Final returns for {stock_ticker}: {returns.iloc[-1]}")

# Create a pair plot for the DataFrame
sns.pairplot(returns_df[1:])
# Out:
# Final returns for C: -0.010516252390057268
# Final returns for GS: -0.009779682435031023
# Final returns for JPM: -0.008409671121790141
# Final returns for MS: -0.013031337263419096
# Final returns for WFC: -0.009655674986336349
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 25
#      22     print(f"Final returns for {stock_ticker}: {returns.iloc[-1]}")
#      24 # Create a pair plot for the DataFrame
# ---> 25 sns.pairplot(dff[1:])
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:2114, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2112 # Set up the PairGrid
#    2113 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2114 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2115                 hue_order=hue_order, palette=palette, corner=corner,
#    2116                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2118 # Add the markers here as PairGrid has figured out how many levels of the
#    2119 # hue variable are needed and we don't want to duplicate that process
#    2120 if markers is not None:
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:1358, in PairGrid.__init__(self, data, hue, vars, x_vars, y_vars, hue_order, palette, hue_kws, corner, diag_sharey, height, aspect, layout_pad, despine, dropna)
#    1356 if despine:
#    1357     utils.despine(fig=fig)
# -> 1358 self.tight_layout(pad=layout_pad)
#
# File ~/anaconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:118, in Grid.tight_layout(self, *args, **kwargs)
#     116 if self._tight_layout_pad is not None:
#     117     kwargs.setdefault("pad", self._tight_layout_pad)
# --> 118 self._figure.tight_layout(*args, **kwargs)
#     119 return self
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/figure.py:3494, in Figure.tight_layout(self, pad, h_pad, w_pad, rect)
#    3492 previous_engine = self.get_layout_engine()
#    3493 self.set_layout_engine(engine)
# -> 3494 engine.execute(self)
#    3495 if not isinstance(previous_engine, TightLayoutEngine) \
#    3496         and previous_engine is not None:
#    3497     _api.warn_external('The figure layout has changed to tight')
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/layout_engine.py:175, in TightLayoutEngine.execute(self, fig)
#     173 renderer = fig._get_renderer()
#     174 with getattr(renderer, "_draw_disabled", nullcontext)():
# --> 175     kwargs = get_tight_layout_figure(
#     176         fig, fig.axes, get_subplotspec_list(fig.axes), renderer,
#     177         pad=info['pad'], h_pad=info['h_pad'], w_pad=info['w_pad'],
#     178         rect=info['rect'])
#     179 if kwargs:
#     180     fig.subplots_adjust(**kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_tight_layout.py:293, in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     290     if top is not None:
#     291         top -= (1 - kwargs["top"])
# --> 293     kwargs = _auto_adjust_subplotpars(fig, renderer,
#     294                                       shape=(max_nrows, max_ncols),
#     295                                       span_pairs=span_pairs,
#     296                                       subplot_list=subplot_list,
#     297                                       ax_bbox_list=ax_bbox_list,
#     298                                       pad=pad, h_pad=h_pad, w_pad=w_pad,
#     299                                       rect=(left, bottom, right, top))
#     301 return kwargs
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/_tight_layout.py:82, in _auto_adjust_subplotpars(fig, renderer, shape, span_pairs, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#      80 for ax in subplots:
#      81     if ax.get_visible():
# ---> 82         bb += [martist._get_tightbbox_for_layout_only(ax, renderer)]
#      84 tight_bbox_raw = Bbox.union(bb)
#      85 tight_bbox = fig.transFigure.inverted().transform_bbox(tight_bbox_raw)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axes/_base.py:4387, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4385 for axis in self._axis_map.values():
#    4386     if self.axison and axis.get_visible():
# -> 4387         ba = martist._get_tightbbox_for_layout_only(axis, renderer)
#    4388         if ba:
#    4389             bb.append(ba)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/artist.py:1415, in _get_tightbbox_for_layout_only(obj, *args, **kwargs)
#    1409 """
#    1410 Matplotlib's `.Axes.get_tightbbox` and `.Axis.get_tightbbox` support a
#    1411 *for_layout_only* kwarg; this helper tries to use the kwarg but skips it
#    1412 when encountering third-party subclasses that do not support it.
#    1413 """
#    1414 try:
# -> 1415     return obj.get_tightbbox(*args, **{**kwargs, "for_layout_only": True})
#    1416 except TypeError:
#    1417     return obj.get_tightbbox(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:1320, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1317     renderer = self.figure._get_renderer()
#    1318 ticks_to_draw = self._update_ticks()
# -> 1320 self._update_label_position(renderer)
#    1322 # go back to just this axis's tick labels
#    1323 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:2308, in XAxis._update_label_position(self, renderer)
#    2304     return
#    2306 # get bounding boxes for this axis and any siblings
#    2307 # that have been set by `fig.align_xlabels()`
# -> 2308 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2310 x, y = self.label.get_position()
#    2311 if self.label_position == 'bottom':
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:2103, in Axis._get_tick_boxes_siblings(self, renderer)
#    2101 for ax in grouper.get_siblings(self.axes):
#    2102     axis = getattr(ax, f"{axis_name}axis")
# -> 2103     ticks_to_draw = axis._update_ticks()
#    2104     tlb, tlb2 = axis._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    2105     bboxes.extend(tlb)
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:1279, in Axis._update_ticks(self)
#    1276 if view_low > view_high:
#    1277     view_low, view_high = view_high, view_low
# -> 1279 interval_t = self.get_transform().transform([view_low, view_high])
#    1281 ticks_to_draw = []
#    1282 for tick in ticks:
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/axis.py:759, in Axis.get_transform(self)
#     758 def get_transform(self):
# --> 759     return self._scale.get_transform()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/scale.py:120, in LinearScale.get_transform(self)
#     115 def get_transform(self):
#     116     """
#     117     Return the transform for linear scaling, which is just the
#     118     `~matplotlib.transforms.IdentityTransform`.
#     119     """
# --> 120     return IdentityTransform()
#
# File ~/anaconda3/lib/python3.10/site-packages/matplotlib/transforms.py:1765, in AffineBase.__init__(self, *args, **kwargs)
#    1764 def __init__(self, *args, **kwargs):
# -> 1765     super().__init__(*args, **kwargs)
#    1766     self._inverted = None
#
# KeyboardInterrupt:

# %%
# worst returns for each bank :
df
# Out:
# Bank Ticker    BAC                                      C                  \
# Stock Info    Open   High    Low  Close    Volume    Open    High     Low
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.00  493.80  481.10
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.60  491.00  483.50
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.40  487.80  484.00
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.80  489.00  482.00
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.00  487.40  483.00
# ...            ...    ...    ...    ...       ...     ...     ...     ...
# 2015-12-24   17.32  17.38  17.22  17.27  29373415   52.48   52.97   52.45
# 2015-12-28   17.22  17.23  16.98  17.13  41777497   52.57   52.57   51.96
# 2015-12-29   17.25  17.35  17.16  17.28  45670376   52.76   53.22   52.74
# 2015-12-30   17.20  17.24  17.04  17.05  35066378   52.84   52.94   52.25
# 2015-12-31   17.01  17.07  16.83  16.83  47152968   52.07   52.39   51.75
#
# Bank Ticker                    ...     MS                                \
# Stock Info    Close    Volume  ...   Open   High    Low  Close   Volume
# Date                           ...
# 2006-01-03   492.90   1537660  ...  57.17  58.49  56.74  58.31  5377000
# 2006-01-04   483.80   1871020  ...  58.70  59.28  58.35  58.35  7977800
# 2006-01-05   486.20   1143160  ...  58.55  58.59  58.02  58.51  5778000
# 2006-01-06   486.20   1370250  ...  58.77  58.85  58.05  58.57  6889800
# 2006-01-09   483.90   1680740  ...  58.63  59.29  58.62  59.19  4144500
# ...             ...       ...  ...    ...    ...    ...    ...      ...
# 2015-12-24    52.71   4671254  ...  32.57  32.71  32.44  32.48  2798163
# 2015-12-28    52.38   8761743  ...  32.36  32.36  31.95  32.17  5420280
# 2015-12-29    52.98  10155134  ...  32.44  32.70  32.32  32.55  6388244
# 2015-12-30    52.30   8763337  ...  32.50  32.64  32.20  32.23  5057162
# 2015-12-31    51.75  11281771  ...  31.91  32.30  31.77  31.81  8154307
#
# Bank Ticker    WFC
# Stock Info    Open   High    Low  Close    Volume
# Date
# 2006-01-03   31.60  31.98  31.20  31.90  11016400
# 2006-01-04   31.80  31.82  31.36  31.53  10871000
# 2006-01-05   31.50  31.56  31.31  31.50  10158000
# 2006-01-06   31.58  31.78  31.38  31.68   8403800
# 2006-01-09   31.68  31.82  31.56  31.68   5619600
# ...            ...    ...    ...    ...       ...
# 2015-12-24   54.97  55.09  54.71  54.82   4999417
# 2015-12-28   54.55  54.78  54.17  54.68   8288841
# 2015-12-29   55.11  55.35  54.99  55.29   7894876
# 2015-12-30   55.27  55.31  54.79  54.89   8016893
# 2015-12-31   54.51  54.95  54.22  54.36  10929767
#
# [2517 rows x 30 columns]

# %%
start_date = '2006-01-01'
end_date = '2016-01-01'

# # Iterate over the unique stock tickers (excluding the 'Stock Info' level)
# for stock_ticker in df.columns.levels[0][1:]:
#     # Extract the 'Close' column for the current stock ticker
#     close_prices = df[stock_ticker]['Close']

#     # Calculate the percentage change over the entire period
#     returns_calculation = close_prices.pct_change()

#     # Get the percentage change for the specified date range
#     returns1 = returns_calculation.loc[start_date:end_date]

#     # Print the final percentage change for the current stock ticker
#     print(f"Final returns for {stock_ticker}: {returns1.iloc[-1]}")

# %%
def rate_of_return(date1,date2,dataFrame):
    start_date = date1
    end_date = date2
    for stock_ticker in dataFrame.columns.levels[0][1:]:
        close_prices = dataFrame[stock_ticker]['Close']
        # Calculate the percentage change over the entire period
        returns_calculation = close_prices.pct_change()

        # Get the percentage change for the specified date range
        returns = returns_calculation.loc[start_date:end_date]

        # Print the final percentage change for the current stock ticker
        print(f"Final returns for {stock_ticker}: {returns.iloc[-1]}")

# %%
rate_of_return(start_date,end_date,df)
# Out:
# Final returns for C: -0.010516252390057268
# Final returns for GS: -0.009779682435031023
# Final returns for JPM: -0.008409671121790141
# Final returns for MS: -0.013031337263419096
# Final returns for WFC: -0.009655674986336349

# %%
# Out:
# Is 2022-01-15 a valid date? Checkdate: n

# %%
# Out:
# n

# %%
# Creating a funtion that would check to see if the date inserted is correct.
k = '2001-07'
r = k.split('-')
print(r)

len(r[0])


# if len(r) != 3:
#     print('invalid date inserted, date is not the correct length')

# elif len(r) == 3:
#     print('date is the correct length, checking  if entry is valid')
#     if r[0].isdigit() == False or r[1].isdigit() == False or r[2].isdigit() == False:
#         print('date is inserted inncorrectly')
        
#     elif r[0].isdigit() == True and r[1].isdigit() == True and r[2].isdigit() == True:
#         print('date is inserted correctly')
# Out:
# ['2001', '07']
# 4

# %%
def check_date(variable, checkdate):
    r = variable.split('-')
    checkdate = '0'

    print(r)
    
    if len(r) != 3: 
        print('invalid date inserted, date is not the correct length')
        checkdate = 'n'
        return checkdate

    elif len(r) == 3:
        print('date is the correct length, checking  if entry is valid')
        if r[0].isdigit() == False or r[1].isdigit() == False or r[2].isdigit() == False:
            print('date is inserted inncorrectly')
            checkdate = 'n'
            return checkdate
        
        elif r[0].isdigit() == True and r[1].isdigit() == True and r[2].isdigit() == True:
            if len(r[0]) != 4 or len(r[1]) != 2 or len(r[2]) != 2:
                print('date is inserted incorrectly')
                checkdate = 'n'
                return checkdate
            elif len(r[0]) == 4 and len(r[1]) == 2 and len(r[2]) == 2:
               print('date is inserted correctly')
               checkdate = 'y'
               return checkdate
    
    return checkdate

# %%
date1 = '20-07-23'

checker = 'asksa'

checker = check_date(date1,checkdate = checker)
print(checker)
# Out:
# ['20', '07', '23']
# date is the correct length, checking  if entry is valid
# date is inserted incorrectly
# n

# %%
# start_date = '2006-01-01'
# end_date = '2016-01-01'

# # Create an empty DataFrame to store the percentage changes
# returns_df = pd.DataFrame()

# # Iterate over the unique stock tickers (excluding the 'Stock Info' level)
# for stock_ticker in df.columns.levels[0][1:]:
#     # Extract the 'Close' column for the current stock ticker
#     close_prices = df[stock_ticker]['Close']

#     # Calculate the percentage change over the entire period
#     returns_calculation = close_prices.pct_change()

#     # Get the percentage change for the specified date range
#     returns = returns_calculation.loc[start_date:end_date]

#     # Append the percentage changes to the returns_df DataFrame
#     returns_df[stock_ticker] = returns

#     # Print the final percentage change for the current stock ticker
#     print(f"Final returns for {stock_ticker}: {returns.iloc[-1]}")

# # Create a pair plot for the DataFrame
# sns.pairplot(returns_df[1:])


def rate_of_return_over_a_period_with_plot(date1,date2,dataframe):
    # create a new empty data frame
    returns_df = pd.DataFrame()
    # first iterate through the data frame:
    for stock_ticker in dataframe.columns.levels[0][1:]:
        close_prices = dataframe[stock_ticker]['Close']
        # calculating raturns
        returns_calculation = close_prices.pct_change()
         # workout the percentage change for the date period inserted
        returns = returns_calculation.loc[date1:date2]
        
        # adding the changes to the 
        returns_df[stock_ticker] = returns

        print(f"Final returns for {stock_ticker}: {returns.iloc[-1]}")
    
    # sns.pairplot(returns_df[1:])

# %%
date_1 = '2006-07-23'
date_2 = '2015-01-01'
rate_of_return_over_a_period_with_plot(date_1,date_2,df)
# Out:
# Final returns for C: -0.01331145149525903
# Final returns for GS: -0.009606049767513114
# Final returns for JPM: -0.009026128266033218
# Final returns for MS: -0.005128205128205221
# Final returns for WFC: -0.01082641645615301

# %%
# This is a function that will allow you to view the max min and standard devation for each stock over a time period
def max_min_std(date1,date2,dataframe):
    returns_df = pd.DataFrame()
    for stock_ticker in dataframe.columns.levels[0][1:]:
        close_prices = dataframe[stock_ticker]['Close']
        # calculating raturns
        returns_calculation = close_prices.pct_change()
         # workout the percentage change for the date period inserted
        returns = returns_calculation.loc[date1:date2]
        returns_df[stock_ticker] = returns

    print('The minimum return for each stock is the following:')
    min_returns_dates = returns_df.idxmin()
    print(returns_df.loc[min_returns_dates, :])
    print('\n')

    print('The maximum return for each stock is The following:')
    max_returns_dates = returns_df.idxmax()
    print(returns_df.loc[max_returns_dates, :])
   

    print('\n')
    print('Now looking at the standard devation for each stock, The one with the highest standard devation value is the riskiest')
    print(returns_df.std())

# %%
max_min_std(date_1,date_2,df)
# Out:
# The minimum return for each stock is the following:
#                    C        GS       JPM        MS       WFC
# Date
# 2011-05-06 -0.899107 -0.002061 -0.002878  0.003978  0.004266
# 2009-01-20 -0.200000 -0.189596 -0.207274 -0.159718 -0.238223
# 2009-01-20 -0.200000 -0.189596 -0.207274 -0.159718 -0.238223
# 2008-10-09 -0.102083 -0.103097 -0.066667 -0.258929 -0.145768
# 2009-01-20 -0.200000 -0.189596 -0.207274 -0.159718 -0.238223
#
#
# The maximum return for each stock is The following:
#                    C        GS       JPM        MS       WFC
# Date
# 2011-05-09  8.769912 -0.006529 -0.001776 -0.006339 -0.001416
# 2008-11-24  0.578249  0.264678  0.213908  0.331343  0.195772
# 2009-01-21  0.310714  0.180743  0.250967  0.287023  0.170063
# 2008-10-13  0.116230  0.250000  0.008405  0.869835  0.073826
# 2008-07-16  0.131181  0.095437  0.158607  0.130645  0.327645
#
#
# Now looking at the standard devation for each stock, The one with the highest standard devation value is the riskiest
# C      0.195696
# GS     0.026840
# JPM    0.029532
# MS     0.040618
# WFC    0.032523
# dtype: float64

# %%
def displot_graph(date1,date2,dataframe,bankname):
    returns_df = pd.DataFrame()
    for stock_ticker in dataframe.columns.levels[0][1:]:
        close_prices = dataframe[stock_ticker]['Close']
        # calculating raturns
        returns_calculation = close_prices.pct_change()
         # workout the percentage change for the date period inserted
        returns = returns_calculation.loc[date1:date2]
        returns_df[stock_ticker] = returns
    sns.displot(returns_df.loc[date1:date2][bankname],color='green',bins=100)

# %%
displot_graph(date_1,date_2,df,'JPM')
# Out:
# /Users/ahmed/anaconda3/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
